# %% [markdown]
# ## XCEPTION NET ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU


from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'DATASET/TRAIN',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 2107 images belonging to 7 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'DATASET/TEST',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 2107 images belonging to 7 classes.

# %%
def xception(input_shape, n_classes):
  
  def conv_bn(x, f, k, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p, use_bias=False)(x)
    x = BatchNormalization()(x)
    return x
  
  
  def sep_bn(x, f, k, s=1, p='same'):
    x = SeparableConv2D(f, k, strides=s, padding=p, use_bias=False)(x)
    x = BatchNormalization()(x)
    return x
  
  
  def entry_flow(x):
    x = conv_bn(x, 32, 3, 2)
    x = ReLU()(x)
    x = conv_bn(x, 64, 3)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, 128, 3)
    x = ReLU()(x)
    x = sep_bn(x, 128, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 128, 1, 2)
    
    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, 256, 3)
    x = ReLU()(x)
    x = sep_bn(x, 256, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 256, 1, 2)
    
    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, 728, 3)
    x = ReLU()(x)
    x = sep_bn(x, 728, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 728, 1, 2)
    x = Add()([tensor, x])
    
    return x
  
  
  def middle_flow(tensor):
    for _ in range(8):
      x = ReLU()(tensor)
      x = sep_bn(x, 728, 3)
      x = ReLU()(x)
      x = sep_bn(x, 728, 3)
      x = ReLU()(x)
      x = sep_bn(x, 728, 3)

      tensor = Add()([tensor, x])
    
    return tensor
  
  
  def exit_flow(tensor):
    x = ReLU()(tensor)
    x = sep_bn(x, 728, 3)
    x = ReLU()(x)
    x = sep_bn(x, 1024, 3)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    tensor = conv_bn(tensor, 1024, 1, 2)
    
    x = Add()([tensor, x])
    x = sep_bn(x, 1536, 3)
    x = ReLU()(x)
    x = sep_bn(x, 2048, 3)
    x = ReLU()(x)
    x = GlobalAvgPool2D()(x)
    x = Dense(n_classes, activation='softmax')(x)
  
    return x
  
  
  input = Input(input_shape)
  
  x = entry_flow(input)
  x = middle_flow(x)
  output = exit_flow(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 7

K.clear_session()
model = xception(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 112, 112, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)         18432     ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 112, 112, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 112, 112, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  separable_conv2d (Separabl  (None, 112, 112, 128)        8768      ['re_lu_1[0][0]']
#  eConv2D)
#
#  batch_normalization_2 (Bat  (None, 112, 112, 128)        512       ['separable_conv2d[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 112, 112, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  separable_conv2d_1 (Separa  (None, 112, 112, 128)        17536     ['re_lu_2[0][0]']
#  bleConv2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)          8192      ['re_lu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 112, 112, 128)        512       ['separable_conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 56, 56, 128)          512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 128)          0         ['batch_normalization_3[0][0]'
#  D)                                                                 ]
#
#  add (Add)                   (None, 56, 56, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  re_lu_3 (ReLU)              (None, 56, 56, 128)          0         ['add[0][0]']
#
#  separable_conv2d_2 (Separa  (None, 56, 56, 256)          33920     ['re_lu_3[0][0]']
#  bleConv2D)
#
#  batch_normalization_5 (Bat  (None, 56, 56, 256)          1024      ['separable_conv2d_2[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  separable_conv2d_3 (Separa  (None, 56, 56, 256)          67840     ['re_lu_4[0][0]']
#  bleConv2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)          32768     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 56, 56, 256)          1024      ['separable_conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 256)          0         ['batch_normalization_6[0][0]'
#  g2D)                                                               ]
#
#  add_1 (Add)                 (None, 28, 28, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'max_pooling2d_1[0][0]']
#
#  re_lu_5 (ReLU)              (None, 28, 28, 256)          0         ['add_1[0][0]']
#
#  separable_conv2d_4 (Separa  (None, 28, 28, 728)          188672    ['re_lu_5[0][0]']
#  bleConv2D)
#
#  batch_normalization_8 (Bat  (None, 28, 28, 728)          2912      ['separable_conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 28, 28, 728)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  separable_conv2d_5 (Separa  (None, 28, 28, 728)          536536    ['re_lu_6[0][0]']
#  bleConv2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 728)          186368    ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 28, 28, 728)          2912      ['separable_conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 14, 14, 728)          2912      ['conv2d_4[0][0]']
#  tchNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 728)          0         ['batch_normalization_9[0][0]'
#  g2D)                                                               ]
#
#  add_2 (Add)                 (None, 14, 14, 728)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_2[0][0]']
#
#  re_lu_7 (ReLU)              (None, 14, 14, 728)          0         ['add_2[0][0]']
#
#  separable_conv2d_6 (Separa  (None, 14, 14, 728)          536536    ['re_lu_7[0][0]']
#  bleConv2D)
#
#  batch_normalization_11 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_6[0][0]']
#  tchNormalization)
#
#  re_lu_8 (ReLU)              (None, 14, 14, 728)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  separable_conv2d_7 (Separa  (None, 14, 14, 728)          536536    ['re_lu_8[0][0]']
#  bleConv2D)
#
#  batch_normalization_12 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_7[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 14, 14, 728)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  separable_conv2d_8 (Separa  (None, 14, 14, 728)          536536    ['re_lu_9[0][0]']
#  bleConv2D)
#
#  batch_normalization_13 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_8[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 14, 14, 728)          0         ['add_2[0][0]',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 14, 14, 728)          0         ['add_3[0][0]']
#
#  separable_conv2d_9 (Separa  (None, 14, 14, 728)          536536    ['re_lu_10[0][0]']
#  bleConv2D)
#
#  batch_normalization_14 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_9[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  separable_conv2d_10 (Separ  (None, 14, 14, 728)          536536    ['re_lu_11[0][0]']
#  ableConv2D)
#
#  batch_normalization_15 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_10[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  separable_conv2d_11 (Separ  (None, 14, 14, 728)          536536    ['re_lu_12[0][0]']
#  ableConv2D)
#
#  batch_normalization_16 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_11[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 14, 14, 728)          0         ['add_3[0][0]',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  re_lu_13 (ReLU)             (None, 14, 14, 728)          0         ['add_4[0][0]']
#
#  separable_conv2d_12 (Separ  (None, 14, 14, 728)          536536    ['re_lu_13[0][0]']
#  ableConv2D)
#
#  batch_normalization_17 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_12[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  separable_conv2d_13 (Separ  (None, 14, 14, 728)          536536    ['re_lu_14[0][0]']
#  ableConv2D)
#
#  batch_normalization_18 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  separable_conv2d_14 (Separ  (None, 14, 14, 728)          536536    ['re_lu_15[0][0]']
#  ableConv2D)
#
#  batch_normalization_19 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 14, 14, 728)          0         ['add_4[0][0]',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 14, 14, 728)          0         ['add_5[0][0]']
#
#  separable_conv2d_15 (Separ  (None, 14, 14, 728)          536536    ['re_lu_16[0][0]']
#  ableConv2D)
#
#  batch_normalization_20 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  separable_conv2d_16 (Separ  (None, 14, 14, 728)          536536    ['re_lu_17[0][0]']
#  ableConv2D)
#
#  batch_normalization_21 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  separable_conv2d_17 (Separ  (None, 14, 14, 728)          536536    ['re_lu_18[0][0]']
#  ableConv2D)
#
#  batch_normalization_22 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 14, 14, 728)          0         ['add_5[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  re_lu_19 (ReLU)             (None, 14, 14, 728)          0         ['add_6[0][0]']
#
#  separable_conv2d_18 (Separ  (None, 14, 14, 728)          536536    ['re_lu_19[0][0]']
#  ableConv2D)
#
#  batch_normalization_23 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  separable_conv2d_19 (Separ  (None, 14, 14, 728)          536536    ['re_lu_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_24 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_19[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  separable_conv2d_20 (Separ  (None, 14, 14, 728)          536536    ['re_lu_21[0][0]']
#  ableConv2D)
#
#  batch_normalization_25 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_20[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 14, 14, 728)          0         ['add_6[0][0]',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  re_lu_22 (ReLU)             (None, 14, 14, 728)          0         ['add_7[0][0]']
#
#  separable_conv2d_21 (Separ  (None, 14, 14, 728)          536536    ['re_lu_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_26 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  separable_conv2d_22 (Separ  (None, 14, 14, 728)          536536    ['re_lu_23[0][0]']
#  ableConv2D)
#
#  batch_normalization_27 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  separable_conv2d_23 (Separ  (None, 14, 14, 728)          536536    ['re_lu_24[0][0]']
#  ableConv2D)
#
#  batch_normalization_28 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_23[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 14, 14, 728)          0         ['add_7[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  re_lu_25 (ReLU)             (None, 14, 14, 728)          0         ['add_8[0][0]']
#
#  separable_conv2d_24 (Separ  (None, 14, 14, 728)          536536    ['re_lu_25[0][0]']
#  ableConv2D)
#
#  batch_normalization_29 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  separable_conv2d_25 (Separ  (None, 14, 14, 728)          536536    ['re_lu_26[0][0]']
#  ableConv2D)
#
#  batch_normalization_30 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  separable_conv2d_26 (Separ  (None, 14, 14, 728)          536536    ['re_lu_27[0][0]']
#  ableConv2D)
#
#  batch_normalization_31 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_26[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 14, 14, 728)          0         ['add_8[0][0]',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  re_lu_28 (ReLU)             (None, 14, 14, 728)          0         ['add_9[0][0]']
#
#  separable_conv2d_27 (Separ  (None, 14, 14, 728)          536536    ['re_lu_28[0][0]']
#  ableConv2D)
#
#  batch_normalization_32 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_27[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  separable_conv2d_28 (Separ  (None, 14, 14, 728)          536536    ['re_lu_29[0][0]']
#  ableConv2D)
#
#  batch_normalization_33 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  separable_conv2d_29 (Separ  (None, 14, 14, 728)          536536    ['re_lu_30[0][0]']
#  ableConv2D)
#
#  batch_normalization_34 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_29[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 14, 14, 728)          0         ['add_9[0][0]',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  re_lu_31 (ReLU)             (None, 14, 14, 728)          0         ['add_10[0][0]']
#
#  separable_conv2d_30 (Separ  (None, 14, 14, 728)          536536    ['re_lu_31[0][0]']
#  ableConv2D)
#
#  batch_normalization_35 (Ba  (None, 14, 14, 728)          2912      ['separable_conv2d_30[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 14, 14, 728)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  separable_conv2d_31 (Separ  (None, 14, 14, 1024)         752024    ['re_lu_32[0][0]']
#  ableConv2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_10[0][0]']
#
#  batch_normalization_36 (Ba  (None, 14, 14, 1024)         4096      ['separable_conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 7, 7, 1024)           4096      ['conv2d_5[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 1024)           0         ['batch_normalization_36[0][0]
#  g2D)                                                               ']
#
#  add_11 (Add)                (None, 7, 7, 1024)           0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_3[0][0]']
#
#  separable_conv2d_32 (Separ  (None, 7, 7, 1536)           1582080   ['add_11[0][0]']
#  ableConv2D)
#
#  batch_normalization_38 (Ba  (None, 7, 7, 1536)           6144      ['separable_conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 7, 7, 1536)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  separable_conv2d_33 (Separ  (None, 7, 7, 2048)           3159552   ['re_lu_33[0][0]']
#  ableConv2D)
#
#  batch_normalization_39 (Ba  (None, 7, 7, 2048)           8192      ['separable_conv2d_33[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 7, 7, 2048)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['re_lu_34[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                    14343     ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 20875823 (79.63 MB)
# Trainable params: 20821295 (79.43 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________
#  batch_normalization_36 (BatchN  (None, 14, 14, 1024  4096       ['separable_conv2d_31[0][0]']
#  ormalization)                  )
#
#  batch_normalization_37 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_5[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['batch_normalization_36[0][0]']
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_37[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 7, 7, 1536)  6144        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 7, 7, 1536)   0           ['batch_normalization_38[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 7, 7, 2048)  3159552     ['re_lu_33[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 7, 7, 2048)  8192        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 7, 7, 2048)   0           ['batch_normalization_39[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['re_lu_34[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 5)            10245       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
model_path = "XCEPTION.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 50
batch_size = 512

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - ETA: 0s - loss: 1.7655 - accuracy: 0.3672 - precision: 0.5139
# Epoch 1: accuracy improved from -inf to 0.36719, saving model to XCEPTION.h5
# 4/4 [==============================] - 77s 17s/step - loss: 1.7655 - accuracy: 0.3672 - precision: 0.5139 - val_loss: 1.9468 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 1.5967 - accuracy: 0.5312 - precision: 0.5657
# Epoch 2: accuracy improved from 0.36719 to 0.53125, saving model to XCEPTION.h5
# 4/4 [==============================] - 58s 15s/step - loss: 1.5967 - accuracy: 0.5312 - precision: 0.5657 - val_loss: 1.9455 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3287 - accuracy: 0.5156 - precision: 0.5165
# Epoch 3: accuracy did not improve from 0.53125
# 4/4 [==============================] - 55s 14s/step - loss: 1.3287 - accuracy: 0.5156 - precision: 0.5165 - val_loss: 1.9455 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0858 - accuracy: 0.4688 - precision: 0.4466
# Epoch 4: accuracy did not improve from 0.53125
# 4/4 [==============================] - 56s 14s/step - loss: 1.0858 - accuracy: 0.4688 - precision: 0.4466 - val_loss: 1.9454 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 1.3834 - accuracy: 0.4375 - precision: 0.4900
# Epoch 5: accuracy did not improve from 0.53125
# 4/4 [==============================] - 56s 15s/step - loss: 1.3834 - accuracy: 0.4375 - precision: 0.4900 - val_loss: 1.9477 - val_accuracy: 0.0859 - val_precision: 0.0000e+00
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0108 - accuracy: 0.5078 - precision: 0.5283
# Epoch 6: accuracy did not improve from 0.53125
# 4/4 [==============================] - 56s 15s/step - loss: 1.0108 - accuracy: 0.5078 - precision: 0.5283 - val_loss: 1.9448 - val_accuracy: 0.2109 - val_precision: 0.0000e+00
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0509 - accuracy: 0.5312 - precision: 0.5345
# Epoch 7: accuracy did not improve from 0.53125
# 4/4 [==============================] - 64s 17s/step - loss: 1.0509 - accuracy: 0.5312 - precision: 0.5345 - val_loss: 1.9461 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9160 - accuracy: 0.5391 - precision: 0.5556
# Epoch 8: accuracy improved from 0.53125 to 0.53906, saving model to XCEPTION.h5
# 4/4 [==============================] - 53s 14s/step - loss: 0.9160 - accuracy: 0.5391 - precision: 0.5556 - val_loss: 1.9455 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0017 - accuracy: 0.5625 - precision: 0.5614
# Epoch 9: accuracy improved from 0.53906 to 0.56250, saving model to XCEPTION.h5
# 4/4 [==============================] - 48s 12s/step - loss: 1.0017 - accuracy: 0.5625 - precision: 0.5614 - val_loss: 1.9464 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8390 - accuracy: 0.5938 - precision: 0.6514
# Epoch 10: accuracy improved from 0.56250 to 0.59375, saving model to XCEPTION.h5
# 4/4 [==============================] - 49s 13s/step - loss: 0.8390 - accuracy: 0.5938 - precision: 0.6514 - val_loss: 1.9464 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9342 - accuracy: 0.5391 - precision: 0.5758
# Epoch 11: accuracy did not improve from 0.59375
# 4/4 [==============================] - 49s 13s/step - loss: 0.9342 - accuracy: 0.5391 - precision: 0.5758 - val_loss: 1.9461 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9561 - accuracy: 0.5469 - precision: 0.5565
# Epoch 12: accuracy did not improve from 0.59375
# 4/4 [==============================] - 51s 13s/step - loss: 0.9561 - accuracy: 0.5469 - precision: 0.5565 - val_loss: 1.9472 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9052 - accuracy: 0.5859 - precision: 0.6132
# Epoch 13: accuracy did not improve from 0.59375
# 4/4 [==============================] - 51s 13s/step - loss: 0.9052 - accuracy: 0.5859 - precision: 0.6132 - val_loss: 1.9441 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0899 - accuracy: 0.5078 - precision: 0.5545
# Epoch 14: accuracy did not improve from 0.59375
# 4/4 [==============================] - 50s 13s/step - loss: 1.0899 - accuracy: 0.5078 - precision: 0.5545 - val_loss: 1.9433 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 1.1023 - accuracy: 0.5000 - precision: 0.5319
# Epoch 15: accuracy did not improve from 0.59375
# 4/4 [==============================] - 50s 13s/step - loss: 1.1023 - accuracy: 0.5000 - precision: 0.5319 - val_loss: 1.9457 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7985 - accuracy: 0.6172 - precision: 0.6701
# Epoch 16: accuracy improved from 0.59375 to 0.61719, saving model to XCEPTION.h5
# 4/4 [==============================] - 54s 14s/step - loss: 0.7985 - accuracy: 0.6172 - precision: 0.6701 - val_loss: 1.9451 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0877 - accuracy: 0.4766 - precision: 0.4915
# Epoch 17: accuracy did not improve from 0.61719
# 4/4 [==============================] - 52s 13s/step - loss: 1.0877 - accuracy: 0.4766 - precision: 0.4915 - val_loss: 1.9430 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.6172 - precision: 0.6606
# Epoch 18: accuracy did not improve from 0.61719
# 4/4 [==============================] - 55s 14s/step - loss: 0.8210 - accuracy: 0.6172 - precision: 0.6606 - val_loss: 1.9457 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9282 - accuracy: 0.5547 - precision: 0.5575
# Epoch 19: accuracy did not improve from 0.61719
# 4/4 [==============================] - 59s 13s/step - loss: 0.9282 - accuracy: 0.5547 - precision: 0.5575 - val_loss: 1.9449 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7477 - accuracy: 0.6250 - precision: 0.6887
# Epoch 20: accuracy improved from 0.61719 to 0.62500, saving model to XCEPTION.h5
# 4/4 [==============================] - 57s 15s/step - loss: 0.7477 - accuracy: 0.6250 - precision: 0.6887 - val_loss: 1.9443 - val_accuracy: 0.2188 - val_precision: 0.0000e+00
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 1.0524 - accuracy: 0.5078 - precision: 0.5140
# Epoch 21: accuracy did not improve from 0.62500
# 4/4 [==============================] - 46s 12s/step - loss: 1.0524 - accuracy: 0.5078 - precision: 0.5140 - val_loss: 1.9421 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.5938 - precision: 0.6132
# Epoch 22: accuracy did not improve from 0.62500
# 4/4 [==============================] - 47s 12s/step - loss: 0.8055 - accuracy: 0.5938 - precision: 0.6132 - val_loss: 1.9439 - val_accuracy: 0.2734 - val_precision: 0.0000e+00
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9072 - accuracy: 0.6094 - precision: 0.6372
# Epoch 23: accuracy did not improve from 0.62500
# 4/4 [==============================] - 46s 12s/step - loss: 0.9072 - accuracy: 0.6094 - precision: 0.6372 - val_loss: 1.9431 - val_accuracy: 0.2578 - val_precision: 0.0000e+00
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.7109 - precision: 0.7288
# Epoch 24: accuracy improved from 0.62500 to 0.71094, saving model to XCEPTION.h5
# 4/4 [==============================] - 50s 13s/step - loss: 0.6454 - accuracy: 0.7109 - precision: 0.7288 - val_loss: 1.9405 - val_accuracy: 0.1953 - val_precision: 0.0000e+00
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9712 - accuracy: 0.5781 - precision: 0.6228
# Epoch 25: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.9712 - accuracy: 0.5781 - precision: 0.6228 - val_loss: 1.9432 - val_accuracy: 0.2656 - val_precision: 0.0000e+00
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 0.9318 - accuracy: 0.6328 - precision: 0.6429
# Epoch 26: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.9318 - accuracy: 0.6328 - precision: 0.6429 - val_loss: 1.9390 - val_accuracy: 0.2578 - val_precision: 0.0000e+00
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7105 - accuracy: 0.6719 - precision: 0.6875
# Epoch 27: accuracy did not improve from 0.71094
# 4/4 [==============================] - 51s 14s/step - loss: 0.7105 - accuracy: 0.6719 - precision: 0.6875 - val_loss: 1.9445 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8365 - accuracy: 0.6484 - precision: 0.6579
# Epoch 28: accuracy did not improve from 0.71094
# 4/4 [==============================] - 46s 12s/step - loss: 0.8365 - accuracy: 0.6484 - precision: 0.6579 - val_loss: 1.9418 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7843 - accuracy: 0.6172 - precision: 0.6607
# Epoch 29: accuracy did not improve from 0.71094
# 4/4 [==============================] - 49s 13s/step - loss: 0.7843 - accuracy: 0.6172 - precision: 0.6607 - val_loss: 1.9442 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6406 - precision: 0.6667
# Epoch 30: accuracy did not improve from 0.71094
# 4/4 [==============================] - 57s 14s/step - loss: 0.8446 - accuracy: 0.6406 - precision: 0.6667 - val_loss: 1.9410 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.5625 - precision: 0.5804
# Epoch 31: accuracy did not improve from 0.71094
# 4/4 [==============================] - 53s 14s/step - loss: 0.7903 - accuracy: 0.5625 - precision: 0.5804 - val_loss: 1.9439 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8252 - accuracy: 0.6016 - precision: 0.6087
# Epoch 32: accuracy did not improve from 0.71094
# 4/4 [==============================] - 46s 12s/step - loss: 0.8252 - accuracy: 0.6016 - precision: 0.6087 - val_loss: 1.9441 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.5859 - precision: 0.6216
# Epoch 33: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.8055 - accuracy: 0.5859 - precision: 0.6216 - val_loss: 1.9371 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 0.8802 - accuracy: 0.6094 - precision: 0.6239
# Epoch 34: accuracy did not improve from 0.71094
# 4/4 [==============================] - 46s 12s/step - loss: 0.8802 - accuracy: 0.6094 - precision: 0.6239 - val_loss: 1.9432 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.6875 - precision: 0.7034
# Epoch 35: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.6596 - accuracy: 0.6875 - precision: 0.7034 - val_loss: 1.9412 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7295 - accuracy: 0.6406 - precision: 0.6964
# Epoch 36: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.7295 - accuracy: 0.6406 - precision: 0.6964 - val_loss: 1.9357 - val_accuracy: 0.2422 - val_precision: 0.0000e+00
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7636 - accuracy: 0.5781 - precision: 0.5917
# Epoch 37: accuracy did not improve from 0.71094
# 4/4 [==============================] - 47s 12s/step - loss: 0.7636 - accuracy: 0.5781 - precision: 0.5917 - val_loss: 1.9379 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.6641 - precision: 0.6881
# Epoch 38: accuracy did not improve from 0.71094
# 4/4 [==============================] - 46s 12s/step - loss: 0.7901 - accuracy: 0.6641 - precision: 0.6881 - val_loss: 1.9347 - val_accuracy: 0.2109 - val_precision: 0.0000e+00
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7728 - accuracy: 0.6875 - precision: 0.7009
# Epoch 39: accuracy did not improve from 0.71094
# 4/4 [==============================] - 46s 12s/step - loss: 0.7728 - accuracy: 0.6875 - precision: 0.7009 - val_loss: 1.9310 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6142 - accuracy: 0.7188 - precision: 0.7227
# Epoch 40: accuracy improved from 0.71094 to 0.71875, saving model to XCEPTION.h5
# 4/4 [==============================] - 50s 13s/step - loss: 0.6142 - accuracy: 0.7188 - precision: 0.7227 - val_loss: 1.9365 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.6406 - precision: 0.6957
# Epoch 41: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.6392 - accuracy: 0.6406 - precision: 0.6957 - val_loss: 1.9329 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7568 - accuracy: 0.6406 - precision: 0.6724
# Epoch 42: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.7568 - accuracy: 0.6406 - precision: 0.6724 - val_loss: 1.9213 - val_accuracy: 0.2734 - val_precision: 0.0000e+00
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.6797 - precision: 0.7119
# Epoch 43: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.6525 - accuracy: 0.6797 - precision: 0.7119 - val_loss: 1.9266 - val_accuracy: 0.2344 - val_precision: 0.0000e+00
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6720 - accuracy: 0.6911 - precision: 0.6991
# Epoch 44: accuracy did not improve from 0.71875
# 4/4 [==============================] - 47s 12s/step - loss: 0.6720 - accuracy: 0.6911 - precision: 0.6991 - val_loss: 1.9231 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.6875 - precision: 0.6860
# Epoch 45: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.7023 - accuracy: 0.6875 - precision: 0.6860 - val_loss: 1.9470 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7507 - accuracy: 0.5938 - precision: 0.6016
# Epoch 46: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.7507 - accuracy: 0.5938 - precision: 0.6016 - val_loss: 1.9282 - val_accuracy: 0.2422 - val_precision: 0.0000e+00
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6824 - accuracy: 0.7031 - precision: 0.7131
# Epoch 47: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.6824 - accuracy: 0.7031 - precision: 0.7131 - val_loss: 1.9232 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 0.6648 - accuracy: 0.6797 - precision: 0.6911
# Epoch 48: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.6648 - accuracy: 0.6797 - precision: 0.6911 - val_loss: 1.9266 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.5703 - precision: 0.5776
# Epoch 49: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.7236 - accuracy: 0.5703 - precision: 0.5776 - val_loss: 1.9200 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 0.7852 - accuracy: 0.6641 - precision: 0.6777
# Epoch 50: accuracy did not improve from 0.71875
# 4/4 [==============================] - 46s 12s/step - loss: 0.7852 - accuracy: 0.6641 - precision: 0.6777 - val_loss: 1.9262 - val_accuracy: 0.1406 - val_precision: 0.0000e+00

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
